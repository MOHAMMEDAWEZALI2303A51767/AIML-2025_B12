# %% [markdown]
# <a href="https://colab.research.google.com/github/MOHAMMEDAWEZALI2303A51767/AIML-2025_B12/blob/main/AIML_LAB_1_(PART2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
people=['Ann','suraj','maaz','siduu']
age=[12,33,44,56]
weight=[22,55,85,94]
height=[160,156,123,146]
import matplotlib.pyplot as plt
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()
plt.figure(figsize=(15,6))
plt.title("People's weight in kgs",fontsize=16,
          fontstyle='italic')

plt.bar(x=people,height=weight, width=0.88,
        color='blue',edgecolor='k',alpha=0.88)

plt.xlabel("People",fontsize=16)
plt.ylabel("Weight (in kgs)",fontsize=16)
plt.show()
import numpy as np
plt.figure(figsize=(4,9))
plt.hist(weight,color='black',edgecolor='k', alpha=0.75,bins=5)

plt.title("Histogram of patient weight",fontsize=15)
plt.xlabel("Weight in kgs",fontsize=13)
plt.show()
